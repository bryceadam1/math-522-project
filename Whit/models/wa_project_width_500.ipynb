# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
cd "Colab Notebooks/"
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# cd wa_522_proj
# path = '/MyDrive/Colab Notebooks/wa_522_proj/'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

import torch.backends
from torch.nn import Module, Linear, ReLU, Sequential
from torch.optim import SGD
from torch.nn import MSELoss

if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.backends.cudnn.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# device = torch.device("cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
plt.rcParams['figure.figsize'] = (5,5)

# %% [markdown]
# # Generate Data

# %%
f = np.sin

x = np.linspace(- np.pi, np.pi, 100)
eps = np.random.normal(0, 0.1, 100)

y = f(x) + eps

plt.scatter(x, y, s=1)
plt.show()

x_train = x
y_train = y

# %%
# Create Data Set
x = torch.tensor(x, dtype=torch.float32, device=device).reshape(-1, 1)
y = torch.tensor(y, dtype=torch.float32, device=device).reshape(-1, 1)

# Create Data Loader
batch_size = 10
data = torch.utils.data.TensorDataset(x, y)
loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)

# %% [markdown]
# # Train Model

# %%
class NNModel(Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(NNModel, self).__init__()

        self.num_layers = num_layers

        self.linear_in = Linear(input_size, hidden_size)
        self.linear_out = Linear(hidden_size, output_size)
        self.relu = ReLU()

        mids = [Linear(hidden_size, hidden_size) for _ in range(num_layers)]
        self.seq = Sequential(*[layer for sublist in zip(mids, [ReLU()]*num_layers) for layer in sublist])
        
    def forward(self, x):
        out = self.linear_in(x)
        out = self.seq(out)
        out = self.relu(out)
        out = self.linear_out(out)
        return out
      

def initialize(fhat):
    # Initialize weights to be close to 0
    for param in fhat.parameters():
        param.data.normal_(0, 0.01)

def train(fhat):
    # Training Loop
    optimizer = SGD(fhat.parameters(), lr=0.01)
    reg = 0.001
    criterion = MSELoss()
    epochs = 1001

    losses = []
    for epoch in range(epochs):
        for x, y in loader:
            optimizer.zero_grad()
            yhat = fhat(x)
            
            loss = criterion(yhat, y) + reg * (torch.sum(fhat.linear_in.weight ** 2) + torch.sum(fhat.linear_out.weight ** 2))
            for layer in fhat.seq[::2]:
              loss += reg * torch.sum(layer.weight**2)

            loss.backward()
            optimizer.step()
        if epoch % 100 == 0:
            print("Epoch: %d, Loss: %f" % (epoch, loss.item()))
        losses.append(loss.item())
    
    return np.array(losses)

# %%
#n_params = np.arange(100, 20001, 100)
n_layers = np.arange(1,21)

for l in n_layers:
    print(f"Training model with {l} layers")
    fhat = NNModel(1, 500, l, 1).to(device)
    initialize(fhat)
    loss = train(fhat)

    # Save the model
    my_dict = fhat.state_dict()
    torch.save(my_dict, f"models500/model_{l}.pt")

    # Save the loss
    np.save(f"models500/loss_{l}.npy", loss)

    print()
# Out:
# Training model with 1 layers
# Epoch: 0, Loss: 0.404554
# Epoch: 100, Loss: 0.095332
# Epoch: 200, Loss: 0.201103
# Epoch: 300, Loss: 0.069271
# Epoch: 400, Loss: 0.041844
# Epoch: 500, Loss: 0.042533
# Epoch: 600, Loss: 0.035784
# Epoch: 700, Loss: 0.034287
# Epoch: 800, Loss: 0.039736
# Epoch: 900, Loss: 0.031902
# Epoch: 1000, Loss: 0.044698
#
# Training model with 2 layers
# Epoch: 0, Loss: 0.590633
# Epoch: 100, Loss: 0.511717
# Epoch: 200, Loss: 0.122174
# Epoch: 300, Loss: 0.098569
# Epoch: 400, Loss: 0.096697
# Epoch: 500, Loss: 0.062362
# Epoch: 600, Loss: 0.060809
# Epoch: 700, Loss: 0.056306
# Epoch: 800, Loss: 0.048531
# Epoch: 900, Loss: 0.049073
# Epoch: 1000, Loss: 0.047272
#
# Training model with 3 layers
# Epoch: 0, Loss: 0.537527
# Epoch: 100, Loss: 0.569549
# Epoch: 200, Loss: 0.628228
# Epoch: 300, Loss: 0.501975
# Epoch: 400, Loss: 0.341599
# Epoch: 500, Loss: 0.169662
# Epoch: 600, Loss: 0.182451
# Epoch: 700, Loss: 0.099842
# Epoch: 800, Loss: 0.143699
# Epoch: 900, Loss: 0.093889
# Epoch: 1000, Loss: 0.080631
#
# Training model with 4 layers
# Epoch: 0, Loss: 0.715518
# Epoch: 100, Loss: 0.433290
# Epoch: 200, Loss: 0.560068
# Epoch: 300, Loss: 0.370988
# Epoch: 400, Loss: 0.550699
# Epoch: 500, Loss: 0.530834
# Epoch: 600, Loss: 0.559672
# Epoch: 700, Loss: 0.605123
# Epoch: 800, Loss: 0.626361
# Epoch: 900, Loss: 0.540445
# Epoch: 1000, Loss: 0.821885
#
# Training model with 5 layers
# Epoch: 0, Loss: 0.500221
# Epoch: 100, Loss: 0.876140
# Epoch: 200, Loss: 0.694804
# Epoch: 300, Loss: 0.716933
# Epoch: 400, Loss: 0.438826
# Epoch: 500, Loss: 0.840326
# Epoch: 600, Loss: 0.621920
# Epoch: 700, Loss: 0.625541
# Epoch: 800, Loss: 0.535659
# Epoch: 900, Loss: 0.722277
# Epoch: 1000, Loss: 0.485348
#
# Training model with 6 layers
# Epoch: 0, Loss: 0.752842
# Epoch: 100, Loss: 0.903194
# Epoch: 200, Loss: 0.653609
# Epoch: 300, Loss: 0.470444
# Epoch: 400, Loss: 0.579758
# Epoch: 500, Loss: 0.607416
# Epoch: 600, Loss: 0.392145
# Epoch: 700, Loss: 0.592482
# Epoch: 800, Loss: 0.627055
# Epoch: 900, Loss: 0.443200
# Epoch: 1000, Loss: 0.413788
#
# Training model with 7 layers
# Epoch: 0, Loss: 0.493896
# Epoch: 100, Loss: 0.563041
# Epoch: 200, Loss: 0.577254
# Epoch: 300, Loss: 0.952839
# Epoch: 400, Loss: 0.563335
# Epoch: 500, Loss: 0.641669
# Epoch: 600, Loss: 0.744502
# Epoch: 700, Loss: 0.615709
# Epoch: 800, Loss: 0.604764
# Epoch: 900, Loss: 0.749544
# Epoch: 1000, Loss: 0.653938
#
# Training model with 8 layers
# Epoch: 0, Loss: 0.629455
# Epoch: 100, Loss: 0.724351
# Epoch: 200, Loss: 0.744670
# Epoch: 300, Loss: 0.661180
# Epoch: 400, Loss: 0.644130
# Epoch: 500, Loss: 0.752056
# Epoch: 600, Loss: 0.473442
# Epoch: 700, Loss: 0.871644
# Epoch: 800, Loss: 0.447844
# Epoch: 900, Loss: 0.653189
# Epoch: 1000, Loss: 0.520195
#
# Training model with 9 layers
# Epoch: 0, Loss: 0.819053
# Epoch: 100, Loss: 0.788274
# Epoch: 200, Loss: 0.531108
# Epoch: 300, Loss: 0.794906
# Epoch: 400, Loss: 0.658015
# Epoch: 500, Loss: 0.500754
# Epoch: 600, Loss: 0.633883
# Epoch: 700, Loss: 0.653024
# Epoch: 800, Loss: 0.685984
# Epoch: 900, Loss: 0.521823
# Epoch: 1000, Loss: 0.565965
#
# Training model with 10 layers
# Epoch: 0, Loss: 0.787142
# Epoch: 100, Loss: 0.875865
# Epoch: 200, Loss: 0.509989
# Epoch: 300, Loss: 0.710210
# Epoch: 400, Loss: 0.725464
# Epoch: 500, Loss: 0.641662
# Epoch: 600, Loss: 0.894538
# Epoch: 700, Loss: 0.664075
# Epoch: 800, Loss: 0.404592
# Epoch: 900, Loss: 0.521356
# Epoch: 1000, Loss: 0.721993
#
# Training model with 11 layers
# Epoch: 0, Loss: 0.702854
# Epoch: 100, Loss: 0.694496
# Epoch: 200, Loss: 0.634733
# Epoch: 300, Loss: 0.824210
# Epoch: 400, Loss: 0.776751
# Epoch: 500, Loss: 0.499147
# Epoch: 600, Loss: 0.613165
# Epoch: 700, Loss: 0.475043
# Epoch: 800, Loss: 0.481550
# Epoch: 900, Loss: 0.682853
# Epoch: 1000, Loss: 0.818559
#
# Training model with 12 layers
# Epoch: 0, Loss: 0.905490
# Epoch: 100, Loss: 0.893916
# Epoch: 200, Loss: 0.918109
# Epoch: 300, Loss: 0.939803
# Epoch: 400, Loss: 0.641787
# Epoch: 500, Loss: 0.684281
# Epoch: 600, Loss: 0.917717
# Epoch: 700, Loss: 0.818327
# Epoch: 800, Loss: 0.556792
# Epoch: 900, Loss: 0.785681
# Epoch: 1000, Loss: 0.648042
#
# Training model with 13 layers
# Epoch: 0, Loss: 0.777809
# Epoch: 100, Loss: 1.016349
# Epoch: 200, Loss: 0.705379
# Epoch: 300, Loss: 0.767968
# Epoch: 400, Loss: 0.732633
# Epoch: 500, Loss: 0.594275
# Epoch: 600, Loss: 0.739887
# Epoch: 700, Loss: 0.695514
# Epoch: 800, Loss: 0.765586
# Epoch: 900, Loss: 0.604100
# Epoch: 1000, Loss: 0.760632
#
# Training model with 14 layers
# Epoch: 0, Loss: 0.917674
# Epoch: 100, Loss: 0.757756
# Epoch: 200, Loss: 0.764338
# Epoch: 300, Loss: 0.742279
# Epoch: 400, Loss: 0.876232
# Epoch: 500, Loss: 1.037087
# Epoch: 600, Loss: 0.893652
# Epoch: 700, Loss: 0.567620
# Epoch: 800, Loss: 0.607636
# Epoch: 900, Loss: 0.696471
# Epoch: 1000, Loss: 0.703518
#
# Training model with 15 layers
# Epoch: 0, Loss: 0.837180
# Epoch: 100, Loss: 0.826043
# Epoch: 200, Loss: 0.714074
# Epoch: 300, Loss: 0.852345
# Epoch: 400, Loss: 0.948751
# Epoch: 500, Loss: 0.779626
# Epoch: 600, Loss: 0.872087
# Epoch: 700, Loss: 0.623207
# Epoch: 800, Loss: 0.792881
# Epoch: 900, Loss: 0.831155
# Epoch: 1000, Loss: 0.708764
#
# Training model with 16 layers
# Epoch: 0, Loss: 0.968832
# Epoch: 100, Loss: 0.912671
# Epoch: 200, Loss: 0.798483
# Epoch: 300, Loss: 0.732381
# Epoch: 400, Loss: 0.852155
# Epoch: 500, Loss: 0.784045
# Epoch: 600, Loss: 1.111462
# Epoch: 700, Loss: 0.680309
# Epoch: 800, Loss: 0.696429
# Epoch: 900, Loss: 0.845396
# Epoch: 1000, Loss: 0.719022
#
# Training model with 17 layers
# Epoch: 0, Loss: 0.813398
# Epoch: 100, Loss: 1.108173
# Epoch: 200, Loss: 1.176180
# Epoch: 300, Loss: 1.103331
# Epoch: 400, Loss: 0.711482
# Epoch: 500, Loss: 1.112364
# Epoch: 600, Loss: 0.955502
# Epoch: 700, Loss: 0.658259
# Epoch: 800, Loss: 0.611208
# Epoch: 900, Loss: 0.814747
# Epoch: 1000, Loss: 0.970826
#
# Training model with 18 layers
# Epoch: 0, Loss: 0.908695
# Epoch: 100, Loss: 1.021722
# Epoch: 200, Loss: 0.931949
# Epoch: 300, Loss: 0.944540
# Epoch: 400, Loss: 0.888608
# Epoch: 500, Loss: 0.807262
# Epoch: 600, Loss: 0.813815
# Epoch: 700, Loss: 0.845035
# Epoch: 800, Loss: 0.730903
# Epoch: 900, Loss: 0.850563
# Epoch: 1000, Loss: 0.704472
#
# Training model with 19 layers
# Epoch: 0, Loss: 0.964023
# Epoch: 100, Loss: 1.035417
# Epoch: 200, Loss: 0.980083
# Epoch: 300, Loss: 0.818867
# Epoch: 400, Loss: 0.782806
# Epoch: 500, Loss: 0.943562
# Epoch: 600, Loss: 0.777303
# Epoch: 700, Loss: 0.848184
# Epoch: 800, Loss: 0.858933
# Epoch: 900, Loss: 0.745692
# Epoch: 1000, Loss: 0.766002
#
# Training model with 20 layers
# Epoch: 0, Loss: 0.907786
# Epoch: 100, Loss: 0.905320
# Epoch: 200, Loss: 0.872849
# Epoch: 300, Loss: 0.949567
# Epoch: 400, Loss: 1.033670
# Epoch: 500, Loss: 0.785299
# Epoch: 600, Loss: 0.938414
# Epoch: 700, Loss: 1.033963
# Epoch: 800, Loss: 0.886566
# Epoch: 900, Loss: 0.879084
# Epoch: 1000, Loss: 0.759562

# %%
n_params = 500

fhat1 = NNModel(1, n_params, 1, 1).to(device)
fhat1.load_state_dict(torch.load(f'models{n_params}/model_1.pt'))

fhat2 = NNModel(1, n_params, 2, 1).to(device)
fhat2.load_state_dict(torch.load(f'models{n_params}/model_2.pt'))

fhat3 = NNModel(1, n_params, 3, 1).to(device)
fhat3.load_state_dict(torch.load(f'models{n_params}/model_3.pt'))

fhat4 = NNModel(1, n_params, 4, 1).to(device)
fhat4.load_state_dict(torch.load(f'models{n_params}/model_4.pt'))

fhat5 = NNModel(1, n_params, 5, 1).to(device)
fhat5.load_state_dict(torch.load(f'models{n_params}/model_5.pt'))

fhat6 = NNModel(1, n_params, 6, 1).to(device)
fhat6.load_state_dict(torch.load(f'models{n_params}/model_6.pt'))

fhat7 = NNModel(1, n_params, 7, 1).to(device)
fhat7.load_state_dict(torch.load(f'models{n_params}/model_7.pt'))

fhat8 = NNModel(1, n_params, 8, 1).to(device)
fhat8.load_state_dict(torch.load(f'models{n_params}/model_8.pt'))

fhat9 = NNModel(1, n_params, 9, 1).to(device)
fhat9.load_state_dict(torch.load(f'models{n_params}/model_9.pt'))

fhat10 = NNModel(1, n_params, 10, 1).to(device)
fhat10.load_state_dict(torch.load(f'models{n_params}/model_10.pt'))

fhat11 = NNModel(1, n_params, 11, 1).to(device)
fhat11.load_state_dict(torch.load(f'models{n_params}/model_11.pt'))

fhat12 = NNModel(1, n_params, 12, 1).to(device)
fhat12.load_state_dict(torch.load(f'models{n_params}/model_12.pt'))

fhat13 = NNModel(1, n_params, 13, 1).to(device)
fhat13.load_state_dict(torch.load(f'models{n_params}/model_13.pt'))

fhat14 = NNModel(1, n_params, 14, 1).to(device)
fhat14.load_state_dict(torch.load(f'models{n_params}/model_14.pt'))

fhat15 = NNModel(1, n_params, 15, 1).to(device)
fhat15.load_state_dict(torch.load(f'models{n_params}/model_15.pt'))

fhat16 = NNModel(1, n_params, 16, 1).to(device)
fhat16.load_state_dict(torch.load(f'models{n_params}/model_16.pt'))

fhat17 = NNModel(1, n_params, 17, 1).to(device)
fhat17.load_state_dict(torch.load(f'models{n_params}/model_17.pt'))

fhat18 = NNModel(1, n_params, 18, 1).to(device)
fhat18.load_state_dict(torch.load(f'models{n_params}/model_18.pt'))

fhat19 = NNModel(1, n_params, 19, 1).to(device)
fhat19.load_state_dict(torch.load(f'models{n_params}/model_19.pt'))

fhat20 = NNModel(1, n_params, 20, 1).to(device)
fhat20.load_state_dict(torch.load(f'models{n_params}/model_20.pt'))

my_models = [fhat1, fhat2, fhat3, fhat4, fhat5, fhat6, fhat7, fhat8, fhat9, fhat10, fhat11, fhat12, fhat13, fhat14, fhat15, fhat16, fhat17, fhat18, fhat19, fhat20]

# %% [markdown]
# # Test the suckers

# %%
dom_test = np.linspace(-np.pi, np.pi, 100)
eps_test = np.random.normal(0, 0.1, 100)

range_test = f(dom_test) + eps_test

plt.scatter(dom_test, range_test, s=1)
plt.show()

# %%
# Create Data Set
x_test = torch.tensor(dom_test, dtype=torch.float32, device=device).reshape(-1, 1)
y_test = torch.tensor(range_test, dtype=torch.float32, device=device).reshape(-1, 1)

# Create Data Loader
batch_size = 10
data_test = torch.utils.data.TensorDataset(x_test, y_test)
loader_test = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)

# %%
preds = []
diffs = []

for fhat in my_models:
  preds.append(fhat(x_test).cpu().detach().numpy())
  diffs.append(preds[-1]-f(dom_test))

# %%
plt.figure(figsize=(10,10))

for i, pred in enumerate(preds):
  plt.subplot(5,4,i+1)
  plt.plot(pred)

plt.tight_layout()
plt.show()

# %%
my_MSE = [np.mean(diff**2) for diff in diffs]
plt.plot(np.arange(1,21),my_MSE)
plt.show()

# %%
my_MSE = [np.mean(diff**2) for diff in diffs[:10]]
plt.plot(np.arange(1,11),my_MSE)
plt.title('500 params per layer')
plt.xlabel('Layers (of 500)')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# # 10000 for 1 to 5 layers

# %%
dom = np.linspace(-np.pi, np.pi, 1000)
x = torch.tensor(dom, dtype=torch.float32, device=device).reshape(-1, 1)
y = torch.tensor(np.sin(dom), dtype=torch.float32, device=device).reshape(-1, 1)
pred = np.squeeze(fhat20(x).cpu().detach().numpy())
diff = pred - f(dom)

plt.hist(pred-f(dom), bins=100, density=True)
plt.show()

# %%
pred1 = np.squeeze(fhat1(x_test).cpu().detach().numpy())
diff1 = pred1 - f(dom_test)

pred2 = np.squeeze(fhat2(x_test).cpu().detach().numpy())
diff2 = pred2 - f(dom_test)

pred3 = np.squeeze(fhat3(x_test).cpu().detach().numpy())
diff3 = pred3 - f(dom_test)

pred4 = np.squeeze(fhat4(x_test).cpu().detach().numpy())
diff4 = pred4 - f(dom_test)

pred5 = np.squeeze(fhat5(x_test).cpu().detach().numpy())
diff5 = pred5 - f(dom_test)

# %%
plt.plot(np.arange(1,6)*10000, [np.mean(diff1**2), np.mean(diff2**2), np.mean(diff3**2), np.mean(diff4**2), np.mean(diff5**2)])
plt.show()

# %%
plt.plot(dom_test, diff1, label='1 layer')
plt.plot(dom_test, diff2, label='2 layer')
plt.plot(dom_test, diff3, label='3 layer')
plt.plot(dom_test, diff4, label='4 layer')
plt.plot(dom_test, diff5, label='5 layer')
plt.legend()
plt.show()
